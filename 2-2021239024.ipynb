# %% [markdown]
# # Exercise 2 - Basics of Machine Learning (Conceptual and Applied)

# %% [markdown]
# **1) For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.**

# %% [markdown]
# **a) The sample size n is extremely large, and the number of predictors p is small.**

# %% [markdown]
# So we know that having a large number of samples helps the model to be more accurate since all sorts and data can be included. Now when it comes to the impact of the number of predictors on a flexible model's performance - it doesn't directly affect the performance. But, having less number of predictors helps to avoid the risk of the model overfitting. Reduced number of predictors shrinks the hypothesis space (the set of functions the model can fit). In lower dimensions, flexible models are less likely to find weird functions that fit noise in data. Its always better to have only the features that acutally helps determine the output, having features that doesn't have much relation with output are useless.
#
# Think of it like this : Its easier to draw a curve through 10 points in a 2D space then to do on an 100D space.

# %% [markdown]
# **b) The number of predictors p is extremely large, and the number of observations n is small.**

# %% [markdown]
# Having a large of number of predictors generally is useful to attain more accuracy as many complex relationships can be identified, thus minimizing loss function. But in this case since the sample size is small, there is a risk of overfitting. The model will be fit perfectly on the training data and may fail on test data.
#
# Think of it like this : With 10 points and 1000 features, the model can easily learn a zero error function - but fail utterly on new data.

# %% [markdown]
# **c) The relationship between the predictors and response is highly non-linear.**

# %% [markdown]
# When the relation between input and output variables is non linear, it is preferrable to have a flexible model that identifies the complex relationship rather than a linear/rigid model

# %% [markdown]
# **d) The variance of the error terms, i.e. σ 2 = Var("), is extremely high.**

# %% [markdown]
# When the noise in the data is high, flexible methods are more likely to overfit to the noise. In such cases, inflexible methods are preferable because they are more robust to noise, having lower variance and better generalization.Variance

# %% [markdown]
# **2) Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.**

# %% [markdown]
# **a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.**

# %% [markdown]
# Type: Regression
# → CEO salary is a continuous variable.
#
# Goal: Inference
# → The goal is to understand which predictors affect CEO salary, not just predict.
#
# 𝑛: 500 firms (observations)
#
# 𝑝: 3 predictors
# → Profit, Number of employees, Industry
# (CEO salary is the response, not a predictor)

# %% [markdown]
# **b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.**

# %% [markdown]
# Type: Classification
# → The response is binary (success/failure).
#
# Goal: Prediction
# → The aim is to predict the outcome of a new product.
#
# 𝑛: 20 products (observations)
#
# 𝑝: 13 predictors
# → Price, Marketing budget, Competition price, and 10 others

# %% [markdown]
# **c) We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.**

# %% [markdown]
# Type: Regression
# → The response variable (% change in exchange rate) is continuous.
#
# Goal: Prediction
# → The goal is to predict future exchange rate changes.
#
# 𝑛: 52 weeks (observations for each week in a year)
#
# 𝑝: 3 predictors
# → US, British, and German market changes

# %% [markdown]
# **3) We now revisit the bias-variance decomposition.**

# %% [markdown]
# **a) Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **b) Explain why each of the five curves has the shape displayed in part (a).**

# %% [markdown]
# 1. Bias decreases as flexibility increases because the prediction is more closer to the traing data.
# 2. Variance increases as flexibilty increases beacause as bias decreases the vasriance increases.
# 3. Training error decreases and reaches zero because the model becomes equal to the data as flexibility increases.
# 4. Test error decreases first and increases after some point because as the model fits the error in the training data more it differs from the test data.
# 5. The Bayes error or irreducible error is constant to the data.

# %% [markdown]
# **4) You will now think of some real-life applications for statistical learning.**

# %% [markdown]
# **a) Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.**

# %% [markdown]
# 1. Variants, are they true positives or false positives in NGS data, predictor: variant fraction, cell type, coverage, genomic context, goal: prediction
# 2. Microbial OTUs, - what is the richness of OTUs found by environment. predictors: environmental parameters, goal: prediction, but also inference
# 3. New books, fan-favourites or not based on Goodreads rating, predictors: use parameters of page length, category, author goal: prediction.

# %% [markdown]
# **b) Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.**

# %% [markdown]
# 1. Crime with temperature, goal: prediction and inference
# 2. Price of coffee over time in Switzerland goal:prediction
# 3. Price of used cars by location goal:prediction

# %% [markdown]
# **c) Describe three real-life applications in which cluster analysis might be useful.**

# %% [markdown]
# 1. Microarray or gene expression data - samples with similar patterns
# 2. Microbial communities - samples with similar functional pathways
# 3. People with similar behaviours in financial transaction data

# %% [markdown]
# **5) What are the advantages and disadvantages of a very fexible (versus a less fexible) approach for regression or classifcation? Under what circumstances might a more fexible approach be preferred to a less flexible approach? When might a less fexible approach be preferred?**

# %% [markdown]
# Flexible Approach:
#
# Advantages:
#
# Ability to Capture Complex Patterns: Flexible models can adapt to and capture intricate, non-linear relationships in the data, leading to better performance when the true relationship is complex.
#
# Lower Bias: Because they can model complex patterns, flexible models generally have lower bias. This means they can approximate the underlying relationship between predictors and the response more accurately.
#
# Disadvantages:
#
# High Variance: Flexible models are prone to overfitting, meaning they can model the noise in the training data rather than the true underlying pattern. This leads to high variance, where the model performs well on the training data but poorly on new, unseen data.
#
# Interpretability: Flexible models are usually more complex and less interpretable, making it harder to understand the relationships they have learned or to explain their predictions.
#
# Less Flexible Approach:
#
# Advantages:
#
# Lower Variance: Less flexible models are simpler and less likely to overfit. This means they often generalize better to new data, leading to more reliable predictions.
# Interpretability: These models tend to be simpler and more interpretable, making it easier to understand and communicate the relationships between variables.
#
# Disadvantages:
#
# High Bias: Less flexible models may not capture the true underlying relationship if it is complex, leading to higher bias and potentially worse performance on both training and test data.
#
# Inability to Capture Non-Linearity: These models might fail to capture non-linear relationships, leading to poor model performance if the true data structure is complex.
#
# When to Prefer a More Flexible Approach:
#
# Complex Relationships: When the underlying relationship between predictors and response is highly non-linear or complex, a flexible model is likely to perform better as it can capture these intricate patterns.
#
# Large Sample Size: With a large amount of data, the risk of overfitting is reduced, allowing flexible models to learn complex relationships without suffering too much from high variance.
#
# Predictive Performance Priority: If the goal is to maximize predictive accuracy, especially in situations where the underlying data is not well understood, a more flexible approach might be preferred.
#
# When to Prefer a Less Flexible Approach:
#
# High Variance or Noisy Data: When the data contains a lot of noise or the sample size is small, a less flexible model can help avoid overfitting by being more robust to fluctuations in the data.
#
# Need for Interpretability: In cases where model interpretability is crucial (e.g., in healthcare or finance), a less flexible model that is easier to understand and explain may be preferred.
#
# Computational Constraints: When computational resources are limited, or when real-time predictions are needed, less flexible models are often a better choice due to their lower computational requirements.
#
# Low-dimensional Data: When the number of predictors is small and the relationships are believed to be linear or simple, less flexible models can be sufficient and more efficient.

# %% [markdown]
# **9) This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.**

# %% [markdown]
# **a) Which of the predictors are quantitative, and which are qualitative?**

# %%
import pandas as pd

df = pd.read_csv("Auto.csv")

df.dropna(inplace=True)

data_types = df.dtypes

print(data_types)

quantitative_predictors = [
    col for col in df.columns if data_types[col] in ["int64", "float64"]
]
qualitative_predictors = [col for col in df.columns if data_types[col] == "object"]

print("Quantitative predictors:", quantitative_predictors)
print("Qualitative predictors:", qualitative_predictors)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object
# Quantitative predictors: ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'year', 'origin']
# Qualitative predictors: ['horsepower', 'name']

# %% [markdown]
# **b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.**

# %%
for col in quantitative_predictors:
    min_val = df[col].min()
    max_val = df[col].max()
    print(f"Range of {col}: {min_val} to {max_val}")
# Out:
# Range of mpg: 9.0 to 46.6
# Range of cylinders: 3 to 8
# Range of displacement: 68.0 to 455.0
# Range of weight: 1613 to 5140
# Range of acceleration: 8.0 to 24.8
# Range of year: 70 to 82
# Range of origin: 1 to 3

# %% [markdown]
# **c) What is the mean and standard deviation of each quantitative predictor?**

# %%
for col in quantitative_predictors:
    mean_val = df[col].mean()
    std_dev = df[col].std()
    print(f"Mean of {col}: {mean_val:.2f}")
    print(f"Standard deviation of {col}: {std_dev:.2f}")
# Out:
# Mean of mpg: 23.52
# Standard deviation of mpg: 7.83
# Mean of cylinders: 5.46
# Standard deviation of cylinders: 1.70
# Mean of displacement: 193.53
# Standard deviation of displacement: 104.38
# Mean of weight: 2970.26
# Standard deviation of weight: 847.90
# Mean of acceleration: 15.56
# Standard deviation of acceleration: 2.75
# Mean of year: 75.99
# Standard deviation of year: 3.69
# Mean of origin: 1.57
# Standard deviation of origin: 0.80

# %% [markdown]
# **d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the
# subset of the data that remains?**

# %%
df_subset = df.drop(df.index[9:84])

for col in quantitative_predictors:
    min_val = df_subset[col].min()
    max_val = df_subset[col].max()
    mean_val = df_subset[col].mean()
    std_dev = df_subset[col].std()
    print(f"Range of {col} (subset): {min_val} to {max_val}")
    print(f"Mean of {col} (subset): {mean_val:.2f}")
    print(f"Standard deviation of {col} (subset): {std_dev:.2f}")
# Out:
# Range of mpg (subset): 11.0 to 46.6
# Mean of mpg (subset): 24.45
# Standard deviation of mpg (subset): 7.90
# Range of cylinders (subset): 3 to 8
# Mean of cylinders (subset): 5.37
# Standard deviation of cylinders (subset): 1.65
# Range of displacement (subset): 68.0 to 455.0
# Mean of displacement (subset): 186.77
# Standard deviation of displacement (subset): 99.61
# Range of weight (subset): 1649 to 4997
# Mean of weight (subset): 2931.37
# Standard deviation of weight (subset): 810.71
# Range of acceleration (subset): 8.5 to 24.8
# Mean of acceleration (subset): 15.73
# Standard deviation of acceleration (subset): 2.68
# Range of year (subset): 70 to 82
# Mean of year (subset): 77.14
# Standard deviation of year (subset): 3.12
# Range of origin (subset): 1 to 3
# Mean of origin (subset): 1.60
# Standard deviation of origin (subset): 0.82

# %% [markdown]
# **e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment on your findings.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df)
plt.show()

df_numeric = df.select_dtypes(include=["number"])
df_numeric = df_numeric.fillna(df_numeric.mean())
df_numeric = df_numeric.dropna()

corr_matrix = df_numeric.corr()

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.show()

plt.scatter(df["horsepower"], df["mpg"])
plt.xlabel("Horsepower")
plt.ylabel("MPG")
plt.title("Horsepower vs MPG")
plt.show()

# %% [markdown]
# **f) Suppose that we wish to predict gas mileage (mpg) on the basisof the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your answer.**

# %% [markdown]
# Displacement, weight, horsepower and year. The first three are likely correlated to each other. I think that year also reflects what I assume to be an increase in the efficiency of the motors.
#
# mpg cylinders displacement horsepower weight
#
# mpg 1.0000000 -0.7776175 -0.8051269 -0.7784268 -0.8322442
#
# cylinders -0.7776175 1.0000000 0.9508233 0.8429834 0.8975273
#
# displacement -0.8051269 0.9508233 1.0000000 0.8972570 0.9329944
#
# horsepower -0.7784268 0.8429834 0.8972570 1.0000000 0.8645377
#
# weight -0.8322442 0.8975273 0.9329944 0.8645377 1.0000000
#
# acceleration 0.4233285 -0.5046834 -0.5438005 -0.6891955 -0.4168392
#
# year 0.5805410 -0.3456474 -0.3698552 -0.4163615 -0.3091199
#
# acceleration year
#
# mpg 0.4233285 0.5805410
#
# cylinders -0.5046834 -0.3456474
#
# displacement -0.5438005 -0.3698552
#
# horsepower -0.6891955 -0.4163615
#
# weight -0.4168392 -0.3091199
#
# acceleration 1.0000000 0.2903161
#
# year 0.2903161 1.0000000
#
# Displacement, weight, and horsepower are indeed strongly correlated to each other.
